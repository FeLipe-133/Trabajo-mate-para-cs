# %%
import pandas as pd
import numpy as np

# %%
def check_outliers(raw_data):
    Q1 = np.quantile(raw_data, .25)
    Q3 = np.quantile(raw_data, .75)

    IQR = Q3 - Q1

    low = Q1 - 1.5 * IQR
    high = Q3 + 1.5 * IQR

    row_values = []

    for value in raw_data:
        if value <= high and value>=low:
            row_values.append(0)
        else:
            row_values.append(1)

    return row_values

# %%
df_data= pd.read_csv("../../results/1_check_dataset.csv")
df_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df_data['Pregnancies_outlier'] = check_outliers(df_data['Pregnancies'].values)
df_data['Glucose_outlier'] = check_outliers(df_data['Glucose'].values)
df_data['BloodPressure_outlier'] = check_outliers(df_data['BloodPressure'].values)
df_data['SkinThickness_outlier'] = check_outliers(df_data['SkinThickness'].values)
df_data['Insulin_outlier'] = check_outliers(df_data['Insulin'].values)
df_data['BMI_outlier'] = check_outliers(df_data['BMI'].values)
df_data['DiabetesPedigreeFunction_outlier'] = check_outliers(df_data['DiabetesPedigreeFunction'].values)
df_data['Age_outlier'] = check_outliers(df_data['Age'].values)

# %%
df_data['Pregnancies_outlier'].value_counts()
# Out:
# Pregnancies_outlier
# 0    764
# 1      4
# Name: count, dtype: int64

# %%
df_data['Glucose_outlier'].value_counts() #Aqui no hay outliers :D
# Out:
# Glucose_outlier
# 0    768
# Name: count, dtype: int64

# %%
df_data['BloodPressure_outlier'].value_counts()
# Out:
# BloodPressure_outlier
# 0    754
# 1     14
# Name: count, dtype: int64

# %%
df_data['SkinThickness_outlier'].value_counts()
# Out:
# SkinThickness_outlier
# 0    756
# 1     12
# Name: count, dtype: int64

# %%
df_data['Insulin_outlier'].value_counts()
# Out:
# Insulin_outlier
# 0    679
# 1     89
# Name: count, dtype: int64

# %%
df_data['BMI_outlier'].value_counts()
# Out:
# BMI_outlier
# 0    760
# 1      8
# Name: count, dtype: int64

# %%
df_data['DiabetesPedigreeFunction_outlier'].value_counts()
# Out:
# DiabetesPedigreeFunction_outlier
# 0    739
# 1     29
# Name: count, dtype: int64

# %%
df_data['Age_outlier'].value_counts()
# Out:
# Age_outlier
# 0    759
# 1      9
# Name: count, dtype: int64

# %%
df_data.groupby(by=['Pregnancies_outlier', "Outcome"]).count()
# Out:
#                              Pregnancies  Glucose  BloodPressure  \
# Pregnancies_outlier Outcome
# 0                   0                500      500            500
#                     1                264      264            264
# 1                   1                  4        4              4
#
#                              SkinThickness  Insulin  BMI  \
# Pregnancies_outlier Outcome
# 0                   0                  500      500  500
#                     1                  264      264  264
# 1                   1                    4        4    4
#
#                              DiabetesPedigreeFunction  Age  Glucose_outlier  \
# Pregnancies_outlier Outcome
# 0                   0                             500  500              500
#                     1                             264  264              264
# 1                   1                               4    4                4
#
#                              BloodPressure_outlier  SkinThickness_outlier  \
# Pregnancies_outlier Outcome
# 0                   0                          500                    500
#                     1                          264                    264
# 1                   1                            4                      4
#
#                              Insulin_outlier  BMI_outlier  \
# Pregnancies_outlier Outcome
# 0                   0                    500          500
#                     1                    264          264
# 1                   1                      4            4
#
#                              DiabetesPedigreeFunction_outlier  Age_outlier
# Pregnancies_outlier Outcome
# 0                   0                                     500          500
#                     1                                     264          264
# 1                   1                                       4            4

# %%
df_data.groupby(by=['Insulin_outlier' ,'Pregnancies_outlier','Glucose_outlier' , "Outcome"]).count()
# Out:
#                                                              Pregnancies  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                458
#                                                     1                217
#                 1                   0               1                  4
# 1               0                   0               0                 42
#                                                     1                 47
#
#                                                              Glucose  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0            458
#                                                     1            217
#                 1                   0               1              4
# 1               0                   0               0             42
#                                                     1             47
#
#                                                              BloodPressure  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                  458
#                                                     1                  217
#                 1                   0               1                    4
# 1               0                   0               0                   42
#                                                     1                   47
#
#                                                              SkinThickness  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                  458
#                                                     1                  217
#                 1                   0               1                    4
# 1               0                   0               0                   42
#                                                     1                   47
#
#                                                              Insulin  BMI  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0            458  458
#                                                     1            217  217
#                 1                   0               1              4    4
# 1               0                   0               0             42   42
#                                                     1             47   47
#
#                                                              DiabetesPedigreeFunction  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                             458
#                                                     1                             217
#                 1                   0               1                               4
# 1               0                   0               0                              42
#                                                     1                              47
#
#                                                              Age  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0        458
#                                                     1        217
#                 1                   0               1          4
# 1               0                   0               0         42
#                                                     1         47
#
#                                                              BloodPressure_outlier  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                          458
#                                                     1                          217
#                 1                   0               1                            4
# 1               0                   0               0                           42
#                                                     1                           47
#
#                                                              SkinThickness_outlier  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                          458
#                                                     1                          217
#                 1                   0               1                            4
# 1               0                   0               0                           42
#                                                     1                           47
#
#                                                              BMI_outlier  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                458
#                                                     1                217
#                 1                   0               1                  4
# 1               0                   0               0                 42
#                                                     1                 47
#
#                                                              DiabetesPedigreeFunction_outlier  \
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                                     458
#                                                     1                                     217
#                 1                   0               1                                       4
# 1               0                   0               0                                      42
#                                                     1                                      47
#
#                                                              Age_outlier
# Insulin_outlier Pregnancies_outlier Glucose_outlier Outcome
# 0               0                   0               0                458
#                                                     1                217
#                 1                   0               1                  4
# 1               0                   0               0                 42
#                                                     1                 47

# %%
df_data = df_data[df_data['Pregnancies_outlier'] == 0]
df_data = df_data[df_data['BloodPressure_outlier'] == 0]
df_data = df_data[df_data['SkinThickness_outlier'] == 0]
df_data = df_data[df_data['Insulin_outlier'] == 0]
df_data = df_data[df_data['BMI_outlier'] == 0]
df_data = df_data[df_data['DiabetesPedigreeFunction_outlier'] == 0]
df_data = df_data[df_data['Age_outlier'] == 0]
df_data.shape
# Out:
# (619, 17)

# %%
df_data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome',
#        'Pregnancies_outlier', 'Glucose_outlier', 'BloodPressure_outlier',
#        'SkinThickness_outlier', 'Insulin_outlier', 'BMI_outlier',
#        'DiabetesPedigreeFunction_outlier', 'Age_outlier'],
#       dtype='object')

# %%
df_data = df_data.drop(columns=['Pregnancies_outlier', 'Glucose_outlier', 'BloodPressure_outlier',
       'SkinThickness_outlier', 'Insulin_outlier', 'BMI_outlier',
       'DiabetesPedigreeFunction_outlier', 'Age_outlier'])

df_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 5              5    116.0           74.0      20.536458   79.799479  25.6
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [619 rows x 9 columns]

# %%
df_data.to_csv("../../results/2_removed_outliers.csv", index=False)
